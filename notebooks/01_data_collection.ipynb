# %% [markdown]
# # Notebook 01: Data Collection and Preprocessing
#
# This notebook handles:
# 1. Loading breach data from Privacy Rights Clearinghouse
# 2. Acquiring stock return data from CRSP
# 3. Acquiring firm financial data from Compustat
# 4. Matching data across sources
# 5. Initial data cleaning and validation
#
# **Output:** Clean, merged dataset ready for exploratory data analysis

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Set random seed for reproducibility
np.random.seed(42)

# Define data paths
RAW_DATA_PATH = Path('../data/raw/')
PROCESSED_DATA_PATH = Path('../data/processed/')

print("Setup complete.")
